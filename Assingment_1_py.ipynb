# %%
#1.The area of a triangle with base 8 and height 12.  
base=8 
height=12
area_of_triangle=(base*height)/2 
print("the area of triangle is",area_of_triangle)
# Out:
# the area of triangle is 48.0

# %%
#2.The cube of 5 plus the square of 4. 
import math
cube_number=(5**3)+(4**2) 
print("cube_number is",cube_number)
# Out:
# cube_number is 141

# %%
#3.The absolute difference between 7³ and 3⁷. 
num1=7**3 
num2=3**7 
absolute_difference=abs(num1-num2) 
print("the absolute difference is",absolute_difference)
# Out:
# the absolute difference is 1844

# %%
#4.The sum of digits in the number 4729.  
number = 4729
num1=number//1000
num2=number//100 % 10 
num3=number//10 % 10 
num4=number % 10 
result_sum= num1+num2+num3+num4 
print("the result is",result_sum)
# Out:
# the result is 22

# %%
#4.Your surname repeated 3 times, separated by a dash (-). 
name="manish" 
for i in range(1,4):
    print("your name",name)
# Out:
# your name manish
# your name manish
# your name manish

# %%
#5.Your name right-justified within 20 spaces. 
name = "manish Yadav"
print(name.rjust(20))
# Out:
#         manish Yadav

# %%
#6.The square root of 625 using the math module 
import math  
num=625
result=math.sqrt(num) 
print("the square root os 625 is",result)
# Out:
# the square root os 625 is 25.0

# %%
#7. 200 divided by 12 and show both quotient and remainder  
num1=200 
num2=12 
quotient_result=num1/num2
remainder_result=num1%num2
print("the result of quotient is",quotient_result) 
print("the result of remainder is",remainder_result)
# Out:
# the result of quotient is 16.666666666666668
# the result of remainder is 8

# %%
#8.The integer part of 9.9999 and the rounded value to 2 decimal places. 
int_num=9.9999 
rounded_value=round(int_num,2) 
print("the rounded value after decimal is",rounded_value)
# Out:
# the rounded value after decimal is 10.0

# %%
#9.The Unicode characters corresponding to these codes: 80, 121, 116, 104, 111, 110.
codes = [80, 121, 116, 104, 111, 110]
characters = [chr(code) for code in codes]
result = ''.join(characters)
print("The characters are:", characters)
print("Combined string:", result)
# Out:
# The characters are: ['P', 'y', 't', 'h', 'o', 'n']
# Combined string: Python

# %%
    # PART_2

# %%
#1.Write a program to take a number input from the user and display whether the number is positive, negative, or zero.
num1=input("enter the number") 
if num>0: 
    print("the number is positive") 
elif num<0: 
    print("the number is negative") 
else: 
    print("the number is zero")
# Out:
# enter the number 12
# the number is positive

# %%
#2.Write a program that asks for two integers and displays the remainder and quotient after dividing the first by the second
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
remainder_result=num1%num2
quotient_result=num1//num2 
print("the result of remainder is",remainder_result) 
print("the result of quotient is",quotient_result)
# Out:
# enter the first number 12
# enter the second number 12
# the result of remainder is 0
# the result of quotient is 1

# %%
#3.Write a program to convert Fahrenheit to Celsius and display the result rounded to two decimal places.
num1=float(input("enter the fahrenheit temperature"))  
result=(num1-32)*5 /9 
print("the celsius temperature is",result)
# Out:
# enter the fahrenheit temperature 12
# the celsius temperature is -11.11111111111111

# %%
#4.Write a program that prompts the user for an age, and prints whether the person is a child (below 13), teenager (13–19), or adult (20 and above).
age=int(input("enter the age of child")) 
if age < 13: 
    print("the person is child") 
elif 13 <= age  <=19: 
    print("the person is teenager") 
else : 
    print("the person is adult")
# Out:
# enter the age of child 21
# the person is adult

# %%
#5.Write a program that accepts three numbers from the user and prints the largest among them. 
num1=int(input("enter the first nunber")) 
num2=int(input("enter the second number")) 
num3=int(input("enter the third number")) 
if num1 > num2 and num1 > num3: 
    print("num1 is geater among number",num1) 
elif num2 > num1 and num2 > num3: 
    print("num2 is greater among the number",num2) 
else:
    print("num3 is greater among the number",num3)
# Out:
# enter the first nunber 12
# enter the second number 13
# enter the third number 14
# num3 is greater among the number 14

# %%
#6.Write a program to check whether a given year is a leap year or not. 
no_days=float(input("enter the number of days"))
days=366 
if days > 365: 
    print("the year is  not leap year") 
else: 
    print("the year is  leap year")
# Out:
# enter the number of days 387
# the year is  not leap year

# %%
#7.Write a program that takes a temperature in Celsius and prints whether it’s Cold (<10°C), Warm (10–25°C), or Hot (>25°C). 
temperature=float(input("enter the temperature in celsius")) 
if temperature < 10: 
    print("it is cold") 
elif temperature >= 10 and temperature <= 25:
    print(" the tempeature is warm")  
else: 
    print("the temperature is hot")
# Out:
# enter the temperature in celsius 9
# it is cold

# %%
#8.Write a program to take a character input and display whether it is a vowel or consonant.
ch = input("Enter a character: ")

if ch.lower() in ['a', 'e', 'i', 'o', 'u']:
    print("It is a Vowel")
else:
    print("It is a Consonant")
# Out:
# Enter a character:  f
# It is a Consonant

# %%
#9.Write a program that asks the user to enter a number between 1 and 7, and displays the corresponding day of the week (1 for Sunday, 2 for Monday, etc.).
user_input=int(input("enter the  number from 1 to 7")) 
if user_input==1: 
    print("today is sunday") 
elif user_input==2: 
    print("today is monday") 
elif user_input==3: 
    print("today id tuesday") 
elif user_input==4: 
    print("today is wednesday") 
elif user_input==5: 
    print("today is thursday") 
elif user_input==6: 
    print("today is friday") 
elif user_input==7: 
    print("today is saturday") 
else: 
    print("please input valid number")
# Out:
# enter the  number from 1 to 7 3
# today id tuesday

# %%
#10.Write a program that takes a distance in kilometers and converts it to miles, displaying the result with exactly three decimal places 
user_input = float(input("Enter the distance in km: "))
miles = user_input * 0.621371 
print("the miles is",miles)
miles = round(miles, 3)
print("The round of miles is:", miles)
# Out:
# Enter the distance in km:  12
# the miles is 7.4564520000000005
# The round of miles is: 7.456

# %%
#11. Write a program to find the Euclidean distance between two coordinates. Take both the coordinates from the user as input. 
import math 
x_1=float(input("enter the x1 vlaue"))
x_2=float(input("enter the x2 vlaue"))
y_1=float(input("enter the y1 vlaue"))
y_2=float(input("enter the y2 vlaue")) 
distance_between=math.sqrt((x_2-x_1)**2 +(y_2- y_1)**2) 
print("the distance between points is",distance_between)
# Out:
# enter the x1 vlaue 2
# enter the x2 vlaue 1
# enter the y1 vlaue 4
# enter the y2 vlaue 3
# the distance between points is 1.4142135623730951

# %%
#12.Write a program to find the simple interest when the value of principle, rate of interest and time period is provided by the user.  
principal=int(input("enter the value of principle")) 
rate=int(input("enter the rate"))
time=int(input("enter the time period")) 
simple_interest=(principal*rate*time)/100 
print("the simple interest is",simple_interest)
# Out:
# enter the value of principle 12
# enter the rate 2
# enter the time period 12
# the simple interest is 2.88

# %%
#13.Write a Python program to find those numbers which are divisible by 7 and multiple of 5, between 1500 and 2000 (both included). 

print("Numbers divisible by 7 and multiple of 5 between 1500 and 2000:")
for num in range(1500, 2001):
    if num % 7 == 0 and num % 5 == 0:
        print(num)

# %%
#14.Write a Python program that accepts a string and calculates the number of digits and letters. 
string_value=input("enter the value of string...") 
print("the number of digits and letter is",len(string_value))
# Out:
# enter the value of string... manish
# the number of digits and letter is 6

# %%
# 15.Write a program to create a number guessing game for the user. The program should ask the user to input a number. The program specifications are as mentioned below. 
 
import random
num = random.randint(1, 10) 
print("Random integer:", num) 
print("Guess a number between 1 and 10. You have 5 attempts.")
for i in range(1,6):  
    user_input=int(input("enter the value of number")) 
    if num==user_input: 
        print("you guess correct number ") 
    elif num < user_input:
       print("you are too close") 
    else: 
       print("game over")
# Out:
# Random integer: 5
# Guess a number between 1 and 10. You have 5 attempts.
# enter the value of number 5
# you guess correct number

# %%
# Asssingment of week_2

# %%
#1.Write a function that takes a string as input and returns:
#The number of digits,
#The number of alphabets
#The number of special characters in that string. 
def string_count(): 
    string=input("enter the string value") 
    print("the number of digits",len(string)) 
    string_count=0
    for char in string_count: 
        if char.isapha(): 
            string_count+=1 
            print
