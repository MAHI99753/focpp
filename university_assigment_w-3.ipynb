# %%
#Modify your greeting program so that if the user does not enter a name (i.e. they
#just press enter), the program responds "Hello, Stranger!". Otherwise it should print
#a greeting with their name as before. 
name = input("Enter your name: ")
if name == "":
    print("Hello, Stranger!")
else:
    print("Hello,", name + "!")
# Out:
# Enter your name:
# Hello, Stranger!

# %%
#2.Write a program that simulates the way in which a user might choose a password.
#The program should prompt for a new password, and then prompt again. If the two
#passwords entered are the same the program should say "Password Set" or
#similar, otherwise it should report an error. 
password_1=input("enter the password") 
password_2=input("enter the password") 
if password_1==password_2: 
    print("the password set") 
else: 
    print("report an error")
# Out:
# enter the password manish
# enter the password maish
# report an error

# %%
#3.Modify your previous program so that the password must be between 8 and 12
#characters (inclusive) long. 
password_1=input("enter the password") 
password_2=input("enter the next password") 
if len(password_1)<8 or len(password_2)>12: 
    print("character must be 8 or 12 character") 
elif password_1==password_2: 
    print("the password set") 
else: 
    print("report error")
# Out:
# enter the password manish123@#
# enter the next password mansihsh123!@#
# character must be 8 or 12 character

# %%
#4.Modify your program again so that the chosen password cannot be one of a list of
#common passwords, defined thus:
#BAD_PASSWORDS = ['password', 'letmein', 'sesame', 'hello', 'justinbieber'] 
BAD_PASSWORDS = ['password', 'letmein', 'sesame', 'hello', 'justinbieber']

password_1 = input("Enter the password: ")

if len(password_1) < 8 or len(password_1) > 12:
    print("Password must be between 8 and 12 characters!")

elif password_1 in BAD_PASSWORDS:
    print("This is a very common password, choose a stronger one!")

else:
    password_2 = input("Re-enter the new password: ")

    if password_1 == password_2:
        print("Password Set")
    else:
        print("Error: Passwords do not match!")
# Out:
# Enter the password:  password
# This is a very common password, choose a stronger one!

# %%
#5.Modify your program a final time so that it executes until the user successfully
#chooses a password. That is, if the password chosen fails any of the checks, the
#program should return to asking for the password the first time. 
BAD_Password = ['password', 'letmein', 'sesame', 'hello', 'justinbieber']

while True:
    password_1 = input("Enter the password: ")

    if len(password_1) < 8 or len(password_1) > 12:
        print("The length of password must be between 8 and 12 characters")
        continue

    elif password_1 in BAD_Password:
        print("This is a common password, choose a strong password")
        continue

    password_2 = input("Enter the password again: ")

    if password_1 == password_2:
        print("Password is set successfully ✅")
        break
    else:
        print("Password does not match, try again ")
# Out:
# Enter the password:  manish@#$$
# Enter the password again:  mnassi
# Password does not match, try again ❌
# Enter the password:  manisg234@#
# Enter the password again:  manish@#$$
# Password does not match, try again ❌
# Enter the password:  manish@#$$

# %%
#6.Write a program that displays the "Seven Times Table". That is, the result of
#multiplying 7 by every number from 0 to 12 inclusive. The output might start:
#0 x 7 = 0
#1 x 7 = 7
#2 x 7 = 14 
for i in range(13):
    result = i * 7
    print(f"{i} x 7 = {result}")
# Out:
# 0 x 7 = 0
# 1 x 7 = 7
# 2 x 7 = 14
# 3 x 7 = 21
# 4 x 7 = 28
# 5 x 7 = 35
# 6 x 7 = 42
# 7 x 7 = 49
# 8 x 7 = 56
# 9 x 7 = 63
# 10 x 7 = 70
# 11 x 7 = 77
# 12 x 7 = 84

# %%
#7.Modify your "Times Table" program so that the user enters the number of the table
#they require. This number should be between 0 and 12 inclusive  
number = int(input("Enter a number between 0 and 12: "))
if 0 <= number <= 12:
    print(f"\nTimes Table for {number}\n")
    for i in range(0, 13):
        print(f"{number} x {i} = {number * i}")
else:
    print("Invalid input! Please enter a number between 0 and 12.")
# Out:
# Enter a number between 0 and 12:  11
# Times Table for 11
#
# 11 x 0 = 0
# 11 x 1 = 11
# 11 x 2 = 22
# 11 x 3 = 33
# 11 x 4 = 44
# 11 x 5 = 55
# 11 x 6 = 66
# 11 x 7 = 77
# 11 x 8 = 88
# 11 x 9 = 99
# 11 x 10 = 110
# 11 x 11 = 121
# 11 x 12 = 132

# %%
#8.Modify the "Times Table" again so that the user still enters the number of the table,
#but if this number is negative the table is printed backwards. So entering "-7"
#would produce the Seven Times Table starting at "12 times" down to "0 times" 
number = int(input("Enter a number between -12 and 12: "))
if -12 <= number <= 12:
    if number < 0:
        number = abs(number)
        print(f"\nTimes Table for {number} (Backwards)\n")
        for i in range(12, -1, -1):
            print(f"{number} x {i} = {number * i}")
    else:
        print(f"\nTimes Table for {number}\n")
        for i in range(0, 13):
            print(f"{number} x {i} = {number * i}")
else:
    print("Invalid input! Please enter a number between -12 and 12.")
# Out:
# Enter a number between -12 and 12:  5
# Times Table for 5
#
# 5 x 0 = 0
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# 5 x 11 = 55
# 5 x 12 = 60

# %%
# Out:
# Enter your password:  manish
# Password is too short. Must be at least 9 characters.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
